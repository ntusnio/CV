index=pd.Index(sm.tsa.datetools.dates_from_range('2009','2015'))
series19.index=pd.Index(sm.tsa.datetools.dates_from_range('2009','2015'))

# %%
for series in [series1,series2,series3,series4,series5,series6,series7,series8,series9,series10,series11,series12,series13,series14,series15,series16,series17,series18,series19]:
    arma_mod01=sm.tsa.ARMA(series,(0,1)).fit()
    print(arma_mod01.predict('2016','2016',dynamic=True))
# Out:
# C:\Users\Python\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency A-DEC will be used.
#   % freq, ValueWarning)
# 2016-12-31    19.340392
# Freq: A-DEC, dtype: float64
# 2016-12-31    19.274354
# Freq: A-DEC, dtype: float64
# 2016-12-31    75.649032
# Freq: A-DEC, dtype: float64
# C:\Users\Python\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency A-DEC will be used.
#   % freq, ValueWarning)
# C:\Users\Python\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency A-DEC will be used.
#   % freq, ValueWarning)
# C:\Users\Python\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency A-DEC will be used.
#   % freq, ValueWarning)
# ...

# %%
from arch import arch_model
for r in [series1,series2,series3,series4,series5,series6,series7,series8,series9,series10,series11,series12,series13,series14,series15,series16,series17,series18,series19]:
    garch11=arch_model(r,p=1,q=1)
    res=garch11.fit()
    forecasts=res.forecast(horizon=1,method='simulation')
    print(forecasts.mean.iloc[-1:])
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 16.1185749672612
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 16.093604044859653
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 16.081368117035215
# Iteration:      4,   Func. Count:     25,   Neg. LLF: 16.07883920311342
# Iteration:      5,   Func. Count:     31,   Neg. LLF: 16.061645836710447
# Iteration:      6,   Func. Count:     37,   Neg. LLF: 15.993934007644544
# Iteration:      7,   Func. Count:     44,   Neg. LLF: 15.991479706870598
# Iteration:      8,   Func. Count:     50,   Neg. LLF: 15.990797647686033
# Iteration:      9,   Func. Count:     56,   Neg. LLF: 15.99074448797992
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 15.990744495084352
#             Iterations: 9
#             Function evaluations: 56
#             Gradient evaluations: 9
#                   h.1
# 2015-12-31  15.715458
# ...

# %%
pd.read_csv('IBD.csv')
# Out:
#                   Region   2009   2010   2011   2012   2013   2014   2015
# 0             Poland (M)   9718   9450  10192  10516  10319  14147  16200
# 1             Poland (F)  11168  10780  11536  11545  11244  16363  19027
# 2      Lower Silesia (M)   1085    929    897    858    932   1146   1342
# 3      Lower Silesia (F)   1162   1043   1022   1065   1058   1409   1651
# 4   Kujawy-Pomerania (M)   1165   1205   1108   1129   1077   1438   1498
# 5   Kujawy-Pomerania (F)   1366   1365   1364   1292   1384   1672   1990
# 6             Lublin (M)    580    479    608    623    499    716    876
# 7             Lublin (F)    629    588    650    659    536    758   1018
# 8             Lubusz (M)    138    140     86     71     87    137    178
# 9             Lubusz (F)    152    138    105     80     96    168    184
# 10              Lodz (M)    637    570    597    565    515    745    943
# 11              Lodz (F)    739    760    738    749    657   1079   1247
# ...
